# %%
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings('ignore')


from utils import preprocess_and_match_vacancy
from binary import train_binary_trebovanyia_model, load_trained_clf

from utils import preprocess_gb_data, preprocess_it_csv, get_matrix_df

# %%
vacancy_url = "https://hh.ru/vacancy/96425465?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+1C&hhtmFrom=vacancy_search_list"
data_gb_path = 'data\data_gb_resultv1.csv'

# %%
matrix = get_matrix_df(vacancy_url, data_gb_path)
# Out:
# 2024-04-28 03:30:56,879 - INFO - Start preprocess_data_from_vacancy_url
# 2024-04-28 03:30:57,074 - INFO - End preprocess_data_from_vacancy_url
# 2024-04-28 03:30:57,076 - INFO - Start preprocess_gb_data
# 2024-04-28 03:30:57,111 - INFO - End preprocess_gb_data

# %%
matrix
# Out:
#                                                        0      1      2   \
# у нас есть опыт реализации проектов различного ...  False  False  False
# устанавливать, обновлять, настраивать и дорабат...  False  False  False
# обучать и консультировать пользователей по веде...  False  False  False
# настраивать обмен между конфигурациями 1с           False  False  False
# настраивать интеграции продуктов 1с между собой...  False  False  False
# прокачивать свои ораторские и наставнические на...  False  False  False
# требования:                                         False  False  False
# законченное высшее или среднее-специальное обра...  False  False  False
# желание развиваться в ит-сфере и работать с про...  False  False  False
# высокая обучаемость и развитое аналитическое мы...  False  False  False
# опыт программирования на любом из языков, или з...  False  False  False
# коммуникабельность, умение слышать другого чело...  False  False  False
#
#                                                        3      4      5   \
# у нас есть опыт реализации проектов различного ...  False  False  False
# устанавливать, обновлять, настраивать и дорабат...  False  False  False
# обучать и консультировать пользователей по веде...  False  False  False
# настраивать обмен между конфигурациями 1с           False  False  False
# настраивать интеграции продуктов 1с между собой...  False  False  False
# прокачивать свои ораторские и наставнические на...  False  False  False
# требования:                                         False  False  False
# законченное высшее или среднее-специальное обра...  False  False  False
# желание развиваться в ит-сфере и работать с про...  False  False  False
# высокая обучаемость и развитое аналитическое мы...  False  False  False
# опыт программирования на любом из языков, или з...  False  False  False
# коммуникабельность, умение слышать другого чело...  False  False  False
#
#                                                        6      7      8   \
# у нас есть опыт реализации проектов различного ...  False  False  False
# устанавливать, обновлять, настраивать и дорабат...  False  False  False
# обучать и консультировать пользователей по веде...  False  False  False
# настраивать обмен между конфигурациями 1с           False  False  False
# настраивать интеграции продуктов 1с между собой...  False  False  False
# прокачивать свои ораторские и наставнические на...  False  False  False
# требования:                                         False  False  False
# законченное высшее или среднее-специальное обра...  False  False  False
# желание развиваться в ит-сфере и работать с про...  False  False  False
# высокая обучаемость и развитое аналитическое мы...  False  False  False
# опыт программирования на любом из языков, или з...  False  False  False
# коммуникабельность, умение слышать другого чело...  False  False  False
#
#                                                        9   ...     18     19  \
# у нас есть опыт реализации проектов различного ...  False  ...  False  False
# устанавливать, обновлять, настраивать и дорабат...  False  ...  False  False
# обучать и консультировать пользователей по веде...  False  ...  False  False
# настраивать обмен между конфигурациями 1с           False  ...  False  False
# настраивать интеграции продуктов 1с между собой...  False  ...  False  False
# прокачивать свои ораторские и наставнические на...  False  ...  False  False
# требования:                                         False  ...  False  False
# законченное высшее или среднее-специальное обра...  False  ...  False  False
# желание развиваться в ит-сфере и работать с про...  False  ...  False  False
# высокая обучаемость и развитое аналитическое мы...  False  ...  False  False
# опыт программирования на любом из языков, или з...  False  ...  False  False
# коммуникабельность, умение слышать другого чело...  False  ...  False  False
#
#                                                        20     21     22  \
# у нас есть опыт реализации проектов различного ...  False  False  False
# устанавливать, обновлять, настраивать и дорабат...  False  False  False
# обучать и консультировать пользователей по веде...  False  False  False
# настраивать обмен между конфигурациями 1с           False  False  False
# настраивать интеграции продуктов 1с между собой...  False  False  False
# прокачивать свои ораторские и наставнические на...  False  False  False
# требования:                                         False  False  False
# законченное высшее или среднее-специальное обра...  False  False  False
# желание развиваться в ит-сфере и работать с про...  False  False  False
# высокая обучаемость и развитое аналитическое мы...  False  False  False
# опыт программирования на любом из языков, или з...  False  False  False
# коммуникабельность, умение слышать другого чело...  False  False  False
#
#                                                        23     24     25  \
# у нас есть опыт реализации проектов различного ...  False  False  False
# устанавливать, обновлять, настраивать и дорабат...  False  False  False
# обучать и консультировать пользователей по веде...  False  False  False
# настраивать обмен между конфигурациями 1с           False  False  False
# настраивать интеграции продуктов 1с между собой...  False  False  False
# прокачивать свои ораторские и наставнические на...  False  False  False
# требования:                                         False  False  False
# законченное высшее или среднее-специальное обра...  False  False  False
# желание развиваться в ит-сфере и работать с про...  False  False  False
# высокая обучаемость и развитое аналитическое мы...  False  False  False
# опыт программирования на любом из языков, или з...  False  False  False
# коммуникабельность, умение слышать другого чело...  False  False  False
#
#                                                        26     27
# у нас есть опыт реализации проектов различного ...  False  False
# устанавливать, обновлять, настраивать и дорабат...  False  False
# обучать и консультировать пользователей по веде...  False  False
# настраивать обмен между конфигурациями 1с           False  False
# настраивать интеграции продуктов 1с между собой...  False  False
# прокачивать свои ораторские и наставнические на...  False  False
# требования:                                         False  False
# законченное высшее или среднее-специальное обра...  False  False
# желание развиваться в ит-сфере и работать с про...  False  False
# высокая обучаемость и развитое аналитическое мы...  False  False
# опыт программирования на любом из языков, или з...  False  False
# коммуникабельность, умение слышать другого чело...  False  False
#
# [12 rows x 28 columns]

# %%
data_it = preprocess_it_csv('data\data_it.csv',)

# %%
testing = pd.read_csv(r'C:\programming\VacancySkillsEstimator\src\test.csv')

# %%
data_it.to_csv('preprocess_it.csv')

# %%
train_binary_trebovanyia_model(r'C:\programming\VacancySkillsEstimator\src\data\trebovanyia_full_data.csv')

# %%
clf = load_trained_clf(r'C:\programming\VacancySkillsEstimator\src\clf.joblib')

# %%
clf

# %%
data = preprocess_and_match_vacancy(vacancy_url=vacancy_url, data_gb_path='data\data_gb_resultv1.csv', data_it_path='data\data_it.csv')

# %%
data.loc[0]

# %%
data.loc[0]['summary']

# %%
datait = pd.read_csv('data\data_it.csv', sep=';')

# %%
datait.loc[datait['region_name'] == 'Москва']
